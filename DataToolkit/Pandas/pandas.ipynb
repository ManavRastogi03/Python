# %%
#Pandas are the data analityic tool build in fast, powerful,flexible

# %%
#very useful with the structure data (tabular data)
import pandas as pd

# %%
df=pd.read_csv("size.csv")
df
# Out:
#           Size Abbreviated Size
# 0  Extra Small               XS
# 1        Small                S
# 2       Medium                M
# 3        Large                L
# 4  Extra Large               XL

# %%
#Panda is consider first row as the col name

# %%
df=pd.read_csv("size.csv",header=None)
df
# Out:
#              0                 1
# 0         Size  Abbreviated Size
# 1  Extra Small                XS
# 2        Small                 S
# 3       Medium                 M
# 4        Large                 L
# 5  Extra Large                XL

# %%
pd.read_csv("size.csv",skiprows=2)#skip first to row while reading the data
# Out:
#          Small   S
# 0       Medium   M
# 1        Large   L
# 2  Extra Large  XL

# %%
pd.read_csv("size.csv",usecols=[0])
# Out:
#           Size
# 0  Extra Small
# 1        Small
# 2       Medium
# 3        Large
# 4  Extra Large

# %%
#data structure >> series and dataframe
#series >> 1 Dimension in nature
#dataframe is two dimension in nature>> multiple series combine together to form the dataframe

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Size
# Out:
# 0    Extra Small
# 1          Small
# 2         Medium
# 3          Large
# 4    Extra Large
# Name: Size, dtype: object

# %%
df['Size']
# Out:
# 0    Extra Small
# 1          Small
# 2         Medium
# 3          Large
# 4    Extra Large
# Name: Size, dtype: object

# %%
type(df['Size'])#a col is the sries in the datafram
# Out:
# pandas.core.series.Series

# %%
l=[1,2,23,4,5]
s=pd.Series(l)

# %%
s
# Out:
# 0     1
# 1     2
# 2    23
# 3     4
# 4     5
# dtype: int64

# %%
s[1:]
# Out:
# 1     2
# 2    23
# 3     4
# 4     5
# dtype: int64

# %%
#by default the index are the interger,we can have custom indexs
d=pd.Series([100,200,300],index=["Ajay","Mnaav",4])

# %%
d
# Out:
# Ajay     100
# Mnaav    200
# 4        300
# dtype: int64

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d["Mnaav"]
# Out:
# np.int64(200)

# %%
#to see all the index in the series 
d.index
# Out:
# Index(['Ajay', 'Mnaav', 4], dtype='object')

# %%
#to reset index
d.reset_index(drop=True)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
pd.DataFrame(d)
# Out:
#          0
# Ajay   100
# Mnaav  200
# 4      300

# %%
#first 5 row
df.head(2)
# Out:
#           Size Abbreviated Size
# 0  Extra Small               XS
# 1        Small                S

# %%
#last to 2 row
df.tail(2)
# Out:
#           Size Abbreviated Size
# 3        Large                L
# 4  Extra Large               XL

# %%
df.shape
# Out:
# (5, 2)

# %%
df.columns
# Out:
# Index(['Size', 'Abbreviated Size'], dtype='object')

# %%
list(df.columns)
# Out:
# ['Size', 'Abbreviated Size']

# %%
df.info
# Out:
# <bound method DataFrame.info of           Size Abbreviated Size
# 0  Extra Small               XS
# 1        Small                S
# 2       Medium                M
# 3        Large                L
# 4  Extra Large               XL>

# %%
df.sample(2)
# Out:
#      Size Abbreviated Size
# 2  Medium                M
# 1   Small                S

# %%
df.info
# Out:
# <bound method DataFrame.info of           Size Abbreviated Size
# 0  Extra Small               XS
# 1        Small                S
# 2       Medium                M
# 3        Large                L
# 4  Extra Large               XL>

# %%
df.dtypes
# Out:
# Size                object
# Abbreviated Size    object
# dtype: object

# %%
df['Size']
# Out:
# 0    Extra Small
# 1          Small
# 2         Medium
# 3          Large
# 4    Extra Large
# Name: Size, dtype: object

# %%
s=pd.Series([1,2,3,4],index=["Manav","Rastogi","Wizard",300])
s
# Out:
# Manav      1
# Rastogi    2
# Wizard     3
# 300        4
# dtype: int64

# %%
pd.DataFrame(s)
# Out:
#          0
# Manav    1
# Rastogi  2
# Wizard   3
# 300      4

# %%
s["new col"]="Manav"

# %%
s
# Out:
# Manav          1
# Rastogi        2
# Wizard         3
# 300            4
# new col    Manav
# dtype: object

# %%
d["new col"]="Manav"

# %%
d
# Out:
# Ajay         100
# Mnaav        200
# 4            300
# new col    Manav
# dtype: object

# %%
#change the col name
df
# Out:
#           Size Abbreviated Size
# 0  Extra Small               XS
# 1        Small                S
# 2       Medium                M
# 3        Large                L
# 4  Extra Large               XL

# %%
df.columns
# Out:
# Index(['Size', 'Abbreviated Size'], dtype='object')

# %%
df.columns=["col1","col2"]

# %%
df
# Out:
#           col1 col2
# 0  Extra Small   XS
# 1        Small    S
# 2       Medium    M
# 3        Large    L
# 4  Extra Large   XL

# %%
#reset the index
d.reset_index(drop=True)
# Out:
# 0      100
# 1      200
# 2      300
# 3    Manav
# dtype: object

# %%
#acessing the two col togther 
#acess one col -->sereis ,multiple col (with squre bracket)
df[["col1","col2"]]
# Out:
#           col1 col2
# 0  Extra Small   XS
# 1        Small    S
# 2       Medium    M
# 3        Large    L
# 4  Extra Large   XL

# %%
df1=pd.read_excel("demo.xls")

# %%
pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 92.2/96.5 kB 880.9 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 791.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df1.shape
# Out:
# (9, 8)

# %%
df1.columns
# Out:
# Index([0, 'First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df1.dtypes
# Out:
# 0              int64
# First Name    object
# Last Name     object
# Gender        object
# Country       object
# Age            int64
# Date          object
# Id             int64
# dtype: object

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df3.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df3.shape
# Out:
# (891, 12)

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df3[["Name","Age","Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                                Heikkinen, Miss Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                        Graham, Miss Margaret Edith  19.0  female
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
df3.to_csv("passenger.csv") #write object in the comma seperated values(csv) file
#to not to get the index of df, pass indec=false

# %%
df3.to_csv("noindex.csv",index=False)

# %%
#how to read json file
url="https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61022',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61022/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61022/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61022/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61022',
#   'id': 2888482040,
#   'node_id': 'PR_kwDOAA0YD86NArDS',
#   'number': 61022,
#   'title': 'BUG: Fix bug in to_datetime that occasionally throws FloatingPointErr…',
#   'user': {'login': 'snitish',
#    'id': 7503884,
#    'node_id': 'MDQ6VXNlcjc1MDM4ODQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7503884?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snitish',
#    'html_url': 'https://github.com/snitish',
# ...
